# %%
#!pip install "numpy<2" --upgrade

# %%
# Check version of numpy -- should be <2 for this code to work
import pandas as pd
# !python -c "import numpy; print(numpy.__version__)"

# %% [markdown]
# # Load demographic data

# %%
import pandas
import os

# This query represents dataset "ndd_dataset_oct_21_25" for domain "person" and was generated for All of Us Controlled Tier Dataset v8
dataset_58436820_person_sql = """
    SELECT
        person.person_id,
        person.gender_concept_id,
        p_gender_concept.concept_name as gender,
        person.birth_datetime as date_of_birth,
        person.race_concept_id,
        p_race_concept.concept_name as race,
        person.ethnicity_concept_id,
        p_ethnicity_concept.concept_name as ethnicity,
        person.sex_at_birth_concept_id,
        p_sex_at_birth_concept.concept_name as sex_at_birth,
        person.self_reported_category_concept_id,
        p_self_reported_category_concept.concept_name as self_reported_category 
    FROM
        `""" + os.environ["WORKSPACE_CDR"] + """.person` person 
    LEFT JOIN
        `""" + os.environ["WORKSPACE_CDR"] + """.concept` p_gender_concept 
            ON person.gender_concept_id = p_gender_concept.concept_id 
    LEFT JOIN
        `""" + os.environ["WORKSPACE_CDR"] + """.concept` p_race_concept 
            ON person.race_concept_id = p_race_concept.concept_id 
    LEFT JOIN
        `""" + os.environ["WORKSPACE_CDR"] + """.concept` p_ethnicity_concept 
            ON person.ethnicity_concept_id = p_ethnicity_concept.concept_id 
    LEFT JOIN
        `""" + os.environ["WORKSPACE_CDR"] + """.concept` p_sex_at_birth_concept 
            ON person.sex_at_birth_concept_id = p_sex_at_birth_concept.concept_id 
    LEFT JOIN
        `""" + os.environ["WORKSPACE_CDR"] + """.concept` p_self_reported_category_concept 
            ON person.self_reported_category_concept_id = p_self_reported_category_concept.concept_id  
    WHERE
        person.PERSON_ID IN (SELECT
            distinct person_id  
        FROM
            `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_person` cb_search_person  
        WHERE
            cb_search_person.person_id IN (SELECT
                criteria.person_id 
            FROM
                (SELECT
                    DISTINCT person_id, entry_date, concept_id 
                FROM
                    `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                WHERE
                    person_id IN (SELECT
                        person_id 
                    FROM
                        `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                    WHERE
                        concept_id IN(SELECT
                            DISTINCT c.concept_id 
                        FROM
                            `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` c 
                        JOIN
                            (SELECT
                                CAST(cr.id as string) AS id       
                            FROM
                                `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` cr       
                            WHERE
                                concept_id IN (44782432, 4220313, 44784643, 4218017)       
                                AND full_text LIKE '%_rank1]%'      ) a 
                                ON (c.path LIKE CONCAT('%.', a.id, '.%') 
                                OR c.path LIKE CONCAT('%.', a.id) 
                                OR c.path LIKE CONCAT(a.id, '.%') 
                                OR c.path = a.id) 
                        WHERE
                            is_standard = 1 
                            AND is_selectable = 1) 
                        AND is_standard = 1 
                    UNION
                    DISTINCT SELECT
                        person_id 
                    FROM
                        `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                    WHERE
                        concept_id IN(SELECT
                            DISTINCT c.concept_id 
                        FROM
                            `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` c 
                        JOIN
                            (SELECT
                                CAST(cr.id as string) AS id       
                            FROM
                                `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` cr       
                            WHERE
                                concept_id IN (1568293, 44826537)       
                                AND full_text LIKE '%_rank1]%'      ) a 
                                ON (c.path LIKE CONCAT('%.', a.id, '.%') 
                                OR c.path LIKE CONCAT('%.', a.id) 
                                OR c.path LIKE CONCAT(a.id, '.%') 
                                OR c.path = a.id) 
                        WHERE
                            is_standard = 0 
                            AND is_selectable = 1) 
                        AND is_standard = 0 )) criteria 
                UNION
                DISTINCT SELECT
                    criteria.person_id 
                FROM
                    (SELECT
                        DISTINCT person_id, entry_date, concept_id 
                    FROM
                        `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                    WHERE
                        person_id IN (SELECT
                            person_id 
                        FROM
                            `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                        WHERE
                            concept_id IN(SELECT
                                DISTINCT c.concept_id 
                            FROM
                                `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` c 
                            JOIN
                                (SELECT
                                    CAST(cr.id as string) AS id       
                                FROM
                                    `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` cr       
                                WHERE
                                    concept_id IN (381270, 4140090)       
                                    AND full_text LIKE '%_rank1]%'      ) a 
                                    ON (c.path LIKE CONCAT('%.', a.id, '.%') 
                                    OR c.path LIKE CONCAT('%.', a.id) 
                                    OR c.path LIKE CONCAT(a.id, '.%') 
                                    OR c.path = a.id) 
                            WHERE
                                is_standard = 1 
                                AND is_selectable = 1) 
                            AND is_standard = 1 
                        UNION
                        DISTINCT SELECT
                            person_id 
                        FROM
                            `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                        WHERE
                            concept_id IN(SELECT
                                DISTINCT c.concept_id 
                            FROM
                                `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` c 
                            JOIN
                                (SELECT
                                    CAST(cr.id as string) AS id       
                                FROM
                                    `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` cr       
                                WHERE
                                    concept_id IN (44826540, 35207329)       
                                    AND full_text LIKE '%_rank1]%'      ) a 
                                    ON (c.path LIKE CONCAT('%.', a.id, '.%') 
                                    OR c.path LIKE CONCAT('%.', a.id) 
                                    OR c.path LIKE CONCAT(a.id, '.%') 
                                    OR c.path = a.id) 
                            WHERE
                                is_standard = 0 
                                AND is_selectable = 1) 
                            AND is_standard = 0 )) criteria 
                    UNION
                    DISTINCT SELECT
                        criteria.person_id 
                    FROM
                        (SELECT
                            DISTINCT person_id, entry_date, concept_id 
                        FROM
                            `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                        WHERE
                            person_id IN (SELECT
                                person_id 
                            FROM
                                `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                            WHERE
                                concept_id IN(SELECT
                                    DISTINCT c.concept_id 
                                FROM
                                    `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` c 
                                JOIN
                                    (SELECT
                                        CAST(cr.id as string) AS id       
                                    FROM
                                        `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` cr       
                                    WHERE
                                        concept_id IN (4182210)       
                                        AND full_text LIKE '%_rank1]%'      ) a 
                                        ON (c.path LIKE CONCAT('%.', a.id, '.%') 
                                        OR c.path LIKE CONCAT('%.', a.id) 
                                        OR c.path LIKE CONCAT(a.id, '.%') 
                                        OR c.path = a.id) 
                                WHERE
                                    is_standard = 1 
                                    AND is_selectable = 1) 
                                AND is_standard = 1 
                            UNION
                            DISTINCT SELECT
                                person_id 
                            FROM
                                `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                            WHERE
                                concept_id IN(SELECT
                                    DISTINCT c.concept_id 
                                FROM
                                    `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` c 
                                JOIN
                                    (SELECT
                                        CAST(cr.id as string) AS id       
                                    FROM
                                        `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` cr       
                                    WHERE
                                        concept_id IN (35207114, 1568088, 1568087)       
                                        AND full_text LIKE '%_rank1]%'      ) a 
                                        ON (c.path LIKE CONCAT('%.', a.id, '.%') 
                                        OR c.path LIKE CONCAT('%.', a.id) 
                                        OR c.path LIKE CONCAT(a.id, '.%') 
                                        OR c.path = a.id) 
                                WHERE
                                    is_standard = 0 
                                    AND is_selectable = 1) 
                                AND is_standard = 0 )) criteria 
                        UNION
                        DISTINCT SELECT
                            criteria.person_id 
                        FROM
                            (SELECT
                                DISTINCT person_id, entry_date, concept_id 
                            FROM
                                `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                            WHERE
                                person_id IN (SELECT
                                    person_id 
                                FROM
                                    `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                                WHERE
                                    concept_id IN(SELECT
                                        DISTINCT c.concept_id 
                                    FROM
                                        `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` c 
                                    JOIN
                                        (SELECT
                                            CAST(cr.id as string) AS id       
                                        FROM
                                            `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` cr       
                                        WHERE
                                            concept_id IN (443605, 379778, 37018688)       
                                            AND full_text LIKE '%_rank1]%'      ) a 
                                            ON (c.path LIKE CONCAT('%.', a.id, '.%') 
                                            OR c.path LIKE CONCAT('%.', a.id) 
                                            OR c.path LIKE CONCAT(a.id, '.%') 
                                            OR c.path = a.id) 
                                    WHERE
                                        is_standard = 1 
                                        AND is_selectable = 1) 
                                    AND is_standard = 1 
                                UNION
                                DISTINCT SELECT
                                    person_id 
                                FROM
                                    `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                                WHERE
                                    concept_id IN(SELECT
                                        DISTINCT c.concept_id 
                                    FROM
                                        `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` c 
                                    JOIN
                                        (SELECT
                                            CAST(cr.id as string) AS id       
                                        FROM
                                            `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` cr       
                                        WHERE
                                            concept_id IN (44831079, 1568087)       
                                            AND full_text LIKE '%_rank1]%'      ) a 
                                            ON (c.path LIKE CONCAT('%.', a.id, '.%') 
                                            OR c.path LIKE CONCAT('%.', a.id) 
                                            OR c.path LIKE CONCAT(a.id, '.%') 
                                            OR c.path = a.id) 
                                    WHERE
                                        is_standard = 0 
                                        AND is_selectable = 1) 
                                    AND is_standard = 0 )) criteria 
                            UNION
                            DISTINCT SELECT
                                criteria.person_id 
                            FROM
                                (SELECT
                                    DISTINCT person_id, entry_date, concept_id 
                                FROM
                                    `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                                WHERE
                                    person_id IN (SELECT
                                        person_id 
                                    FROM
                                        `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                                    WHERE
                                        concept_id IN (373182) 
                                        AND is_standard = 1 
                                    UNION
                                    DISTINCT SELECT
                                        person_id 
                                    FROM
                                        `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                                    WHERE
                                        concept_id IN (44820756, 45571788) 
                                        AND is_standard = 0 )) criteria ) )"""

dataset_58436820_person_df = pandas.read_gbq(
    dataset_58436820_person_sql,
    dialect="standard",
    use_bqstorage_api=("BIGQUERY_STORAGE_API_ENABLED" in os.environ),
    progress_bar_type="tqdm_notebook")

dataset_58436820_person_df.head(5)

# %%
df1 = dataset_58436820_person_df
print(df1.shape)
df1.head()

# %%
df1.race.value_counts()

# %%
# Check sex at birth
df1.sex_at_birth.value_counts()

# %%
# Only select individuals who are male or female and are listed as white to match UKB data
sex_list = ['Male', 'Female']
df1 = df1[['person_id', 'date_of_birth', 'race', 'sex_at_birth']]
df1 = df1[df1['race']=='White']
df1 = df1[df1['sex_at_birth'].isin(sex_list)]
df1[['date_of_birth', 'extra']] = df1.date_of_birth.astype(str).str.split(' ', expand = True)
df1 = df1.drop(columns = ['extra'])
df1

# %%
df1.race.value_counts()

# %% [markdown]
# # Load NDD data

# %%
import pandas
import os

# This query represents dataset "ndd_dataset_oct_21_25" for domain "condition" and was generated for All of Us Controlled Tier Dataset v8
dataset_58436820_condition_sql = """
    SELECT
        c_occurrence.person_id,
        c_occurrence.condition_concept_id,
        c_standard_concept.concept_name as standard_concept_name,
        c_standard_concept.concept_code as standard_concept_code,
        c_standard_concept.vocabulary_id as standard_vocabulary,
        c_occurrence.condition_start_datetime,
        c_occurrence.condition_end_datetime,
        c_occurrence.condition_type_concept_id,
        c_type.concept_name as condition_type_concept_name,
        c_occurrence.stop_reason,
        c_occurrence.visit_occurrence_id,
        visit.concept_name as visit_occurrence_concept_name,
        c_occurrence.condition_source_value,
        c_occurrence.condition_source_concept_id,
        c_source_concept.concept_name as source_concept_name,
        c_source_concept.concept_code as source_concept_code,
        c_source_concept.vocabulary_id as source_vocabulary,
        c_occurrence.condition_status_source_value,
        c_occurrence.condition_status_concept_id,
        c_status.concept_name as condition_status_concept_name 
    FROM
        ( SELECT
            * 
        FROM
            `""" + os.environ["WORKSPACE_CDR"] + """.condition_occurrence` c_occurrence 
        WHERE
            (
                condition_concept_id IN (SELECT
                    DISTINCT c.concept_id 
                FROM
                    `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` c 
                JOIN
                    (SELECT
                        CAST(cr.id as string) AS id       
                    FROM
                        `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` cr       
                    WHERE
                        concept_id IN (35608576, 37018688, 37109056, 37117145, 373182, 374013, 374888, 375791, 376085, 377254, 378125, 378419, 379778, 379784, 380701, 381270, 4043378, 4043379, 4046090, 4047747, 4048875, 4092747, 4101137, 4140090, 4182210, 4196433, 4218017, 4220313, 4277444, 4278830, 43021816, 43530664, 43530666, 443605, 443790, 443864, 444091, 44782432, 44784643, 762497, 762704, 765653)       
                        AND full_text LIKE '%_rank1]%'      ) a 
                        ON (c.path LIKE CONCAT('%.', a.id, '.%') 
                        OR c.path LIKE CONCAT('%.', a.id) 
                        OR c.path LIKE CONCAT(a.id, '.%') 
                        OR c.path = a.id) 
                WHERE
                    is_standard = 1 
                    AND is_selectable = 1) 
                OR  condition_source_concept_id IN (SELECT
                    DISTINCT c.concept_id 
                FROM
                    `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` c 
                JOIN
                    (SELECT
                        CAST(cr.id as string) AS id       
                    FROM
                        `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` cr       
                    WHERE
                        concept_id IN (1568088, 1568090, 1568293, 1568295, 35207114, 35207329, 35207333, 35207356, 35207357, 35207358, 35207359, 37402371, 37402372, 37402373, 37402374, 37402375, 37402377, 37402379, 37402380, 37402383, 37402385, 37402388, 37402390, 37402393, 37402395, 37402398, 37402399, 37402400, 37402401, 37402402, 37402403, 37402404, 37402406, 37402409, 37402410, 37402411, 37402412, 37402414, 37402416, 37402417, 37402418, 37402419, 37402420, 37402422, 37402424, 37402425, 37402426, 37402427, 37402429, 37402430, 37402431, 37402432, 37402433, 37402435, 37402437, 37402438, 37402439, 37402440, 37402441, 37402443, 37402445, 37402446, 37402447, 37402448, 37402451, 37402453, 37402454, 37402456, 44819534, 44819574, 44820708, 44820709, 44820756, 44821810, 44821811, 44821814, 44824105, 44824106, 44824152, 44825328, 44826489, 44826537, 44826540, 44827641, 44827644, 44829914, 44829915, 44829917, 44831078, 44831079, 44831083, 44831122, 44832219, 44833435, 44834581, 44835772,
 44835773, 44835825, 44836954, 44836959, 45538000, 45538103, 45547690, 45552458, 45571788, 45581438, 45591073, 45591076, 45595842, 45595843, 45600684, 45605533, 45942320, 45947757)       
                        AND full_text LIKE '%_rank1]%'      ) a 
                        ON (c.path LIKE CONCAT('%.', a.id, '.%') 
                        OR c.path LIKE CONCAT('%.', a.id) 
                        OR c.path LIKE CONCAT(a.id, '.%') 
                        OR c.path = a.id) 
                WHERE
                    is_standard = 0 
                    AND is_selectable = 1)
            )  
            AND (
                c_occurrence.PERSON_ID IN (SELECT
                    distinct person_id  
                FROM
                    `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_person` cb_search_person  
                WHERE
                    cb_search_person.person_id IN (SELECT
                        criteria.person_id 
                    FROM
                        (SELECT
                            DISTINCT person_id, entry_date, concept_id 
                        FROM
                            `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                        WHERE
                            person_id IN (SELECT
                                person_id 
                            FROM
                                `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                            WHERE
                                concept_id IN(SELECT
                                    DISTINCT c.concept_id 
                                FROM
                                    `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` c 
                                JOIN
                                    (SELECT
                                        CAST(cr.id as string) AS id       
                                    FROM
                                        `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` cr       
                                    WHERE
                                        concept_id IN (44782432, 4220313, 44784643, 4218017)       
                                        AND full_text LIKE '%_rank1]%'      ) a 
                                        ON (c.path LIKE CONCAT('%.', a.id, '.%') 
                                        OR c.path LIKE CONCAT('%.', a.id) 
                                        OR c.path LIKE CONCAT(a.id, '.%') 
                                        OR c.path = a.id) 
                                WHERE
                                    is_standard = 1 
                                    AND is_selectable = 1) 
                                AND is_standard = 1 
                            UNION
                            DISTINCT SELECT
                                person_id 
                            FROM
                                `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                            WHERE
                                concept_id IN(SELECT
                                    DISTINCT c.concept_id 
                                FROM
                                    `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` c 
                                JOIN
                                    (SELECT
                                        CAST(cr.id as string) AS id       
                                    FROM
                                        `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` cr       
                                    WHERE
                                        concept_id IN (1568293, 44826537)       
                                        AND full_text LIKE '%_rank1]%'      ) a 
                                        ON (c.path LIKE CONCAT('%.', a.id, '.%') 
                                        OR c.path LIKE CONCAT('%.', a.id) 
                                        OR c.path LIKE CONCAT(a.id, '.%') 
                                        OR c.path = a.id) 
                                WHERE
                                    is_standard = 0 
                                    AND is_selectable = 1) 
                                AND is_standard = 0 )) criteria 
                        UNION
                        DISTINCT SELECT
                            criteria.person_id 
                        FROM
                            (SELECT
                                DISTINCT person_id, entry_date, concept_id 
                            FROM
                                `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                            WHERE
                                person_id IN (SELECT
                                    person_id 
                                FROM
                                    `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                                WHERE
                                    concept_id IN(SELECT
                                        DISTINCT c.concept_id 
                                    FROM
                                        `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` c 
                                    JOIN
                                        (SELECT
                                            CAST(cr.id as string) AS id       
                                        FROM
                                            `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` cr       
                                        WHERE
                                            concept_id IN (381270, 4140090)       
                                            AND full_text LIKE '%_rank1]%'      ) a 
                                            ON (c.path LIKE CONCAT('%.', a.id, '.%') 
                                            OR c.path LIKE CONCAT('%.', a.id) 
                                            OR c.path LIKE CONCAT(a.id, '.%') 
                                            OR c.path = a.id) 
                                    WHERE
                                        is_standard = 1 
                                        AND is_selectable = 1) 
                                    AND is_standard = 1 
                                UNION
                                DISTINCT SELECT
                                    person_id 
                                FROM
                                    `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                                WHERE
                                    concept_id IN(SELECT
                                        DISTINCT c.concept_id 
                                    FROM
                                        `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` c 
                                    JOIN
                                        (SELECT
                                            CAST(cr.id as string) AS id       
                                        FROM
                                            `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` cr       
                                        WHERE
                                            concept_id IN (44826540, 35207329)       
                                            AND full_text LIKE '%_rank1]%'      ) a 
                                            ON (c.path LIKE CONCAT('%.', a.id, '.%') 
                                            OR c.path LIKE CONCAT('%.', a.id) 
                                            OR c.path LIKE CONCAT(a.id, '.%') 
                                            OR c.path = a.id) 
                                    WHERE
                                        is_standard = 0 
                                        AND is_selectable = 1) 
                                    AND is_standard = 0 )) criteria 
                            UNION
                            DISTINCT SELECT
                                criteria.person_id 
                            FROM
                                (SELECT
                                    DISTINCT person_id, entry_date, concept_id 
                                FROM
                                    `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                                WHERE
                                    person_id IN (SELECT
                                        person_id 
                                    FROM
                                        `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                                    WHERE
                                        concept_id IN(SELECT
                                            DISTINCT c.concept_id 
                                        FROM
                                            `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` c 
                                        JOIN
                                            (SELECT
                                                CAST(cr.id as string) AS id       
                                            FROM
                                                `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` cr       
                                            WHERE
                                                concept_id IN (4182210)       
                                                AND full_text LIKE '%_rank1]%'      ) a 
                                                ON (c.path LIKE CONCAT('%.', a.id, '.%') 
                                                OR c.path LIKE CONCAT('%.', a.id) 
                                                OR c.path LIKE CONCAT(a.id, '.%') 
                                                OR c.path = a.id) 
                                        WHERE
                                            is_standard = 1 
                                            AND is_selectable = 1) 
                                        AND is_standard = 1 
                                    UNION
                                    DISTINCT SELECT
                                        person_id 
                                    FROM
                                        `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                                    WHERE
                                        concept_id IN(SELECT
                                            DISTINCT c.concept_id 
                                        FROM
                                            `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` c 
                                        JOIN
                                            (SELECT
                                                CAST(cr.id as string) AS id       
                                            FROM
                                                `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` cr       
                                            WHERE
                                                concept_id IN (35207114, 1568088, 1568087)       
                                                AND full_text LIKE '%_rank1]%'      ) a 
                                                ON (c.path LIKE CONCAT('%.', a.id, '.%') 
                                                OR c.path LIKE CONCAT('%.', a.id) 
                                                OR c.path LIKE CONCAT(a.id, '.%') 
                                                OR c.path = a.id) 
                                        WHERE
                                            is_standard = 0 
                                            AND is_selectable = 1) 
                                        AND is_standard = 0 )) criteria 
                                UNION
                                DISTINCT SELECT
                                    criteria.person_id 
                                FROM
                                    (SELECT
                                        DISTINCT person_id, entry_date, concept_id 
                                    FROM
                                        `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                                    WHERE
                                        person_id IN (SELECT
                                            person_id 
                                        FROM
                                            `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                                        WHERE
                                            concept_id IN(SELECT
                                                DISTINCT c.concept_id 
                                            FROM
                                                `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` c 
                                            JOIN
                                                (SELECT
                                                    CAST(cr.id as string) AS id       
                                                FROM
                                                    `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` cr       
                                                WHERE
                                                    concept_id IN (443605, 379778, 37018688)       
                                                    AND full_text LIKE '%_rank1]%'      ) a 
                                                    ON (c.path LIKE CONCAT('%.', a.id, '.%') 
                                                    OR c.path LIKE CONCAT('%.', a.id) 
                                                    OR c.path LIKE CONCAT(a.id, '.%') 
                                                    OR c.path = a.id) 
                                            WHERE
                                                is_standard = 1 
                                                AND is_selectable = 1) 
                                            AND is_standard = 1 
                                        UNION
                                        DISTINCT SELECT
                                            person_id 
                                        FROM
                                            `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                                        WHERE
                                            concept_id IN(SELECT
                                                DISTINCT c.concept_id 
                                            FROM
                                                `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` c 
                                            JOIN
                                                (SELECT
                                                    CAST(cr.id as string) AS id       
                                                FROM
                                                    `""" + os.environ["WORKSPACE_CDR"] + """.cb_criteria` cr       
                                                WHERE
                                                    concept_id IN (44831079, 1568087)       
                                                    AND full_text LIKE '%_rank1]%'      ) a 
                                                    ON (c.path LIKE CONCAT('%.', a.id, '.%') 
                                                    OR c.path LIKE CONCAT('%.', a.id) 
                                                    OR c.path LIKE CONCAT(a.id, '.%') 
                                                    OR c.path = a.id) 
                                            WHERE
                                                is_standard = 0 
                                                AND is_selectable = 1) 
                                            AND is_standard = 0 )) criteria 
                                    UNION
                                    DISTINCT SELECT
                                        criteria.person_id 
                                    FROM
                                        (SELECT
                                            DISTINCT person_id, entry_date, concept_id 
                                        FROM
                                            `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                                        WHERE
                                            person_id IN (SELECT
                                                person_id 
                                            FROM
                                                `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                                            WHERE
                                                concept_id IN (373182) 
                                                AND is_standard = 1 
                                            UNION
                                            DISTINCT SELECT
                                                person_id 
                                            FROM
                                                `""" + os.environ["WORKSPACE_CDR"] + """.cb_search_all_events` 
                                            WHERE
                                                concept_id IN (44820756, 45571788) 
                                                AND is_standard = 0 )) criteria ) )
                                        )
                                    ) c_occurrence 
                                LEFT JOIN
                                    `""" + os.environ["WORKSPACE_CDR"] + """.concept` c_standard_concept 
                                        ON c_occurrence.condition_concept_id = c_standard_concept.concept_id 
                                LEFT JOIN
                                    `""" + os.environ["WORKSPACE_CDR"] + """.concept` c_type 
                                        ON c_occurrence.condition_type_concept_id = c_type.concept_id 
                                LEFT JOIN
                                    `""" + os.environ["WORKSPACE_CDR"] + """.visit_occurrence` v 
                                        ON c_occurrence.visit_occurrence_id = v.visit_occurrence_id 
                                LEFT JOIN
                                    `""" + os.environ["WORKSPACE_CDR"] + """.concept` visit 
                                        ON v.visit_concept_id = visit.concept_id 
                                LEFT JOIN
                                    `""" + os.environ["WORKSPACE_CDR"] + """.concept` c_source_concept 
                                        ON c_occurrence.condition_source_concept_id = c_source_concept.concept_id 
                                LEFT JOIN
                                    `""" + os.environ["WORKSPACE_CDR"] + """.concept` c_status 
                                        ON c_occurrence.condition_status_concept_id = c_status.concept_id"""

dataset_58436820_condition_df = pandas.read_gbq(
    dataset_58436820_condition_sql,
    dialect="standard",
    use_bqstorage_api=("BIGQUERY_STORAGE_API_ENABLED" in os.environ),
    progress_bar_type="tqdm_notebook")

dataset_58436820_condition_df.head(5)

# %%
#rename df
df2 = dataset_58436820_condition_df
df2.shape
#df2.head()

# %%
# None of these people should be in controls -- if we want clean controls 
remove = pd.DataFrame(df2.person_id.value_counts()).reset_index()
remove

# %%
remove.to_csv('/home/jupyter/workspace/WORKSPACE_BUCKET/data/people_to_remove_from_controls.csv', header = True, index = False)

# %%
# select columns we need
cases = df2[['person_id', 'standard_concept_name', 'condition_start_datetime', 'source_concept_code']]
cases = cases.sort_values(by = 'condition_start_datetime')

# Make sure we have a start date
cases = cases[~cases['condition_start_datetime'].isna()]
cases

# %%
# Clean up the df and subset the ICD10 codes
cases['condition_start'] = cases.condition_start_datetime.astype(str).str.split(' ').str[0]
cases = cases[['person_id', 'standard_concept_name', 'condition_start', 'source_concept_code']]
cases['icd10'] = cases.source_concept_code.astype(str).str.split('.').str[0]
cases

# %% [markdown]
# # To create these code lists, I tried to match UKB's algorithmically defined codes as much as possible. I included ICD9 & ICD10 codes from UKB's list, and then also included "standard_concept_names" that fit the description

# %% [markdown]
# ## PD cases

# %%
# Codes for PD
pd_codes = ['332.0', 'G20', "Parkinson's disease", 
            "Orthostatic hypotension co-occurrent and due to Parkinson's disease",
 'Young onset Parkinson disease']

# %%
# Pull pd_cases
pd_cases = cases[
    cases['source_concept_code'].isin(pd_codes) |
    cases['icd10'].isin(pd_codes) |
    cases['standard_concept_name'].isin(pd_codes)
]
pd_cases

# %% [markdown]
# ## AD cases

# %%
# Codes for AD
ad_codes = ['331.0', 'F00', 'F00.0', 'F00.1', 'F00.2', 'F00.9', 
            'G30', 'G30.0', 'G30.1', 'G30.8', 'G30.9', 
            "Alzheimer's disease",
           'Primary degenerative dementia of the Alzheimer type, senile onset',
            'Primary degenerative dementia of the Alzheimer type, senile onset, uncomplicated',
            'Dementia of the Alzheimer type with behavioral disturbance',
            'Primary degenerative dementia of the Alzheimer type, presenile onset, uncomplicated',
            "Early onset Alzheimer's disease with behavioral disturbance",
            'Primary degenerative dementia of the Alzheimer type, presenile onset',
            "Altered behavior in Alzheimer's disease",
            "Progressive aphasia in Alzheimer's disease",
            'Behavioral disturbance co-occurrent and due to late onset Alzheimer dementia']

# %%
# Pull AD cases
ad_cases = cases[
    cases['source_concept_code'].isin(ad_codes) |
    cases['icd10'].isin(ad_codes) |
    cases['standard_concept_name'].isin(ad_codes)
]
ad_cases

# %% [markdown]
# ## Dementia cases

# %%
# dementia codes
dem_codes = ['290.2', '290.3', '290.4', '291.2', '294.1', '331.0', '331.1', '331.2', '331.5', 'A81.0',
            'F00', 'F00.0', 'F00.1', 'F00.2', 'F00.9', 'F01', 'F01.0', 'F01.1', 'F01.2', 'F01.3', 'F01.8', 'F01.9',
            'F02', 'F02.0', 'F02.1', 'F02.2', 'F02.3', 'F02.4', 'F02.8', 'F03', 'F05.1', 'F10.6', 
            'G30', 'G30.0', 'G30.1', 'G30.8', 'G30.9', 'G31.0', 'G31.1', 'G31.8',
            "Alzheimer's disease",
           'Primary degenerative dementia of the Alzheimer type, senile onset',
            'Primary degenerative dementia of the Alzheimer type, senile onset, uncomplicated',
            'Dementia of the Alzheimer type with behavioral disturbance',
            'Primary degenerative dementia of the Alzheimer type, presenile onset, uncomplicated',
            "Early onset Alzheimer's disease with behavioral disturbance",
            'Primary degenerative dementia of the Alzheimer type, presenile onset',
            "Altered behavior in Alzheimer's disease",
            "Progressive aphasia in Alzheimer's disease",
            'Behavioral disturbance co-occurrent and due to late onset Alzheimer dementia',
            'Dementia',
             'Dementia associated with another disease',
             'Frontotemporal dementia',
             'Senile dementia of the Lewy body type',
             'Dementia with behavioral disturbance',
             'Dementia associated with alcoholism',
             'Multi-infarct dementia, uncomplicated',
             'Uncomplicated senile dementia',
             'Uncomplicated presenile dementia',
             'Vascular dementia',
             'Presenile dementia with depression',
             'Lewy body dementia with behavioral disturbance',
             'Vascular dementia without behavioral disturbance',
             'Multi-infarct dementia with depression',
             'Psychoactive substance-induced organic dementia',
             'Senile dementia with depression',
             'Post-traumatic dementia with behavioral change',
             'Vascular dementia with behavioral disturbance',
             'Mixed dementia',
             'Multi-infarct dementia with delusions',
             'Multi-infarct dementia with delirium',
             'Presenile dementia',
             'Mild dementia',
             'Dementia due to Huntington chorea',
             'Senile dementia',
             'Senile dementia with delusion',
             'Dementia of frontal lobe type',
             'Behavioral and psychological symptoms of dementia',
             'Multi-infarct dementia',
             'Drug-induced dementia',
             'Presenile dementia with delusions',
             'Mixed cortical and subcortical vascular dementia',
             'Presenile dementia with delirium',
             'Inhalant-induced persisting dementia',
             'Hallucinations co-occurrent and due to late onset dementia',
             'Dementia associated with AIDS',
            "Huntington's chorea",
            'Diffuse Lewy body disease']
print(len(dem_codes))

# %%
# Pull dem cases
dem_cases = cases[
    cases['source_concept_code'].isin(dem_codes) |
    cases['icd10'].isin(dem_codes) |
    cases['standard_concept_name'].isin(dem_codes)
]
dem_cases

# %% [markdown]
# ## checks to make sure we didn't miss any codes

# %%
all_codes = ad_codes + pd_codes + dem_codes

# %%
leftover = cases[~cases['source_concept_code'].isin(all_codes)]
leftover = leftover[~leftover['icd10'].isin(all_codes)]
leftover = leftover[~leftover['standard_concept_name'].isin(all_codes)]
summary = (
    leftover.groupby('standard_concept_name')
      .agg(
          count=('standard_concept_name', 'size'),
          source_concept_codes=('source_concept_code',
                                lambda x: list(pd.unique(x)))
      )
      .reset_index()
      .sort_values('count', ascending=False)
)

summary_list = list(summary['standard_concept_name'])
summary

# %%
# None of these codes should be included in our data -- parkinsonism is explicitly excluded from UKB's PD codes

# %% [markdown]
# # create final files -- rule of two

# %%
#ndd = 'AD'
#final = ad_cases

#ndd = 'PD'
#final = pd_cases
#final

ndd = 'DEM'
final = dem_cases
final

# %%
keep = pd.DataFrame(final.person_id.value_counts()).reset_index()
keep = keep[keep['count'] > 1]
keep_list = list(keep['person_id'])
print(len(keep_list))
final = final[final['person_id'].isin(keep_list)]
final

# %%
final = final.rename(columns = {'condition_start':f'{ndd}_date'})
final

# %%
df1

# %%
# merge dataframe with demographic data
df = final.merge(df1, left_on = 'person_id', right_on = 'person_id', how = 'inner')
df = df.sort_values(by = f'{ndd}_date')
df = df.drop_duplicates(subset = 'person_id', keep = 'first')
df

# %%
df.sex_at_birth.value_counts(dropna=False)

# %%
a = len(df)
print(a)

# %%
#! pwd

# %%
# Save file
df.to_csv(f'/home/jupyter/workspace/WORKSPACE_BUCKET/data/NDD_rule_of_two/{ndd}_cases_n{a}_rule_of_two.csv', header = True, index = False)

# %% [markdown]
# # one code only files

# %%
ndd = 'AD'
final = ad_cases
final

# ndd = 'PD'
# final = pd_cases
# final

# ndd = 'DEM'
# final = dem_cases
# final

# %%
final = final.rename(columns = {'condition_start':f'{ndd}_date'})
final

# %%
df1

# %%
# merge dataframe with demographic data
df = final.merge(df1, left_on = 'person_id', right_on = 'person_id', how = 'inner')
df = df.sort_values(by = f'{ndd}_date')
df = df.drop_duplicates(subset = 'person_id', keep = 'first')
df

# %%
df.sex_at_birth.value_counts(dropna=False)

# %%
a = len(df)
print(a)

# %%
# Save file
df.to_csv(f'data/NDD_one_code/{ndd}_cases_n{a}_one_code.csv', header = True, index = False)
